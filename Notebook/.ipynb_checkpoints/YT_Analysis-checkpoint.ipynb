# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyDxT3MnsKraE5Up2x0rPErC-Tjupm3f3zU'
channel_id = ['UCRWFSbif-RFENbBrSiez1DA','UC6RJ7-PaXg6TIH2BzZfTV7w',
               'UCZFMm1mMw0F81Z37aaEzTUA','UCRWFSbif-RFENbBrSiez1DA',
               'UCF7tJpqRL1kVSAOk3UMfSPQ', 'UC7pluR6rB5KZIbN2IxamzxQ']
youtube = build('youtube','v3',developerKey=api_key)

# %% [markdown]
# ## To get channel Data

# %%
def get_channel_stats(youtube, channel_id):
    all_data=[]
    request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=','.join(channel_id))
    response=request.execute()

    for i in range(len(response['items'])):
      data=dict( Channel_name = response['items'][i]['snippet']['title'],
                 Subscribers = response['items'][i]['statistics']['subscriberCount'],
                 Views = response['items'][i]['statistics']['viewCount'],
                 Total_videos = response['items'][i]['statistics']['videoCount'],
                 Playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads']
               )
      all_data.append(data)
    return all_data

# %%
channel_statistics=get_channel_stats(youtube,channel_id)

# %%
channel_data=pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#        Channel_name Subscribers        Views Total_videos  \
# 0         TIMES NOW     6150000   3171574294       149048
# 1          BolBhidu     2470000   1105620303         7677
# 2  BBC News Marathi     3080000   1452446926        22057
# 3              NDTV    14400000   6404976704       210293
# 4          ABP NEWS    47000000  20566244775       449472
#
#                 Playlist_id
# 0  UU6RJ7-PaXg6TIH2BzZfTV7w
# 1  UUF7tJpqRL1kVSAOk3UMfSPQ
# 2  UU7pluR6rB5KZIbN2IxamzxQ
# 3  UUZFMm1mMw0F81Z37aaEzTUA
# 4  UURWFSbif-RFENbBrSiez1DA

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers     object
# Views           object
# Total_videos    object
# Playlist_id     object
# dtype: object

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# Playlist_id     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(6,8)})
ax=sns.barplot(x='Channel_name',y='Subscribers',data=channel_data)

# %%
ax=sns.barplot(x='Channel_name',y='Views',data=channel_data)

# %%
ax=sns.barplot(x='Channel_name',y='Total_videos',data=channel_data)

# %%
def get_video_ids(youtube,playlist_id):
    request=youtube.playlistItems().list(
                    part = 'contentDetails',
                    playlistId=playlist_id,
                    maxResults=50)
    response = request.execute()
    video_ids=[]
    for i in range(len(response['items'])):
      video_ids.append(response['items'][i]['contentDetails']['videoId'])

    next_page_token = response.get('nextPageToken')
    more_pages=True

    while more_pages:
        if next_page_token is None:
            more_pages=False
        else:
            request=youtube.playlistItems().list(
                    part = 'contentDetails',
                    playlistId=playlist_id,
                    maxResults=50,
                    pageToken= next_page_token)
            response=request.execute()  
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])

            next_page_token = response.get('nextPageToken')
   
    return video_ids

# %%
playlist_id= channel_data.loc[channel_data['Channel_name'] == 'BolBhidu','Playlist_id'].iloc[0]
#video_ids

# %%
video_ids=get_video_ids(youtube,playlist_id)

# %%
video_ids
# Out:
# ['PtXDbXn7gZ0',
#  'jO9yuVRlMkY',
#  'pE7ups9RFR8',
#  'h7MqKgCfzfU',
#  'qmOF4fwMYak',
#  'uQkX6bWT634',
#  'cloIZJbDNAs',
#  'QdzqaDn75Ro',
#  'LyXMfzlkKy0',
#  'BrMtNd9790Y',
#  'ETAqzNb1-R4',
#  '7aYztspsrko',
#  '5A10x0beVt0',
#  '_TurECRQ7ng',
#  'OLt9lajqGz8',
#  'JY4Byi8GkXk',
#  'RZ_iOXdOt_Q',
#  'KHiYR42xIuw',
#  'j3Whe7URsbE',
#  'Nz9fpkJp54Q',
#  '_G1wAwNYpJM',
#  '9J6Ah40pn0I',
#  'qpMnTNKt0Pg',
#  'xpvUIsc34M0',
#  'ORDWTFjmeK8',
#  '56jSUsj-GxY',
#  'EPDASkPxhjY',
#  'qViBpZ6lM6I',
#  '2eddT41lv5E',
#  'y2EG7RzfnjU',
#  'qesXmLe2FDE',
#  'HZ4oj30TbpA',
#  'znNN2eCwQbY',
#  'Q43mNWM9-XY',
#  'UvYGIj5g9M0',
#  '6d1hXQD0RD4',
#  'bA0EcjF4CKY',
#  'YLzvlsDI3pg',
#  '3vWCmCO5Yb0',
#  '2y-LwMa_rWg',
#  'YhJglDTjrwA',
#  'SC02s8QFOBc',
#  '-W2Fxn_qs2Y',
#  '8txlQqM_I_Q',
#  'O1iAQeKQeKA',
#  'oP4-r6Fg8Jc',
#  'ERnPZ6VCJgM',
#  'xBJwSe31Weg',
#  'wUzRZmgxRmI',
#  '5euSkgIkAw4',
#  'A8yf4X5-Mx8',
#  'BW4lJ3CNZaE',
#  'Tz7UTgumrwo',
#  'z1nIj6WbsaQ',
#  '2q00A-N24J4',
#  '8CUJyBYMxuQ',
#  '6gdxJpknN48',
#  'CuTCnSmVxIw',
#  'FcDsygWgCF4',
#  '-MD5Sg58vuU',
#  '0Q-smnW6gnw',
#  'vo5V7UwXpXg',
#  'LlsWztLO-Gk',
#  'yXwGCZ5vUNs',
#  'A_cl2mnkUo8',
#  'QryaOOIq9N4',
#  'fEV8t9G-420',
#  '2zg_HP8djR0',
#  'qUG_OyQmRH8',
#  'At_YD3qIxmY',
#  'rMdAF1GQmTY',
#  'CYnkuXUaxt0',
#  '0LXiR5rWwE8',
#  '1a7VNYOl02U',
#  'p1mjKm7Bl9g',
#  'K_gMvbcHsSI',
#  '51QZlPUUOGw',
#  'RJeJJRPNyOA',
#  'VBzoIhA8Mzs',
#  '0qUifISeX5Y',
#  '83i4prG5ex0',
#  'XiTqLthks6s',
#  'PCjmhWdQ1nI',
#  'AtNl4_VNi6s',
#  'Rsil5nnbEbo',
#  '5ZzBvDwGZyA',
#  '5CHhZAngyFI',
#  'QlClID_5f2Q',
#  '8F7P9S3O45Y',
#  'Z2_bfO--iqw',
#  'faU1K4Muihc',
#  '8lDalxRmSRs',
#  'sLj6vSFmMWw',
#  '70VBy68KbAw',
#  'PyGUkO4jtI8',
#  '9tssrVVYnK4',
#  'By4umJf6B3g',
#  'k2nPiN6KMN4',
#  'w4ybE1DojPM',
#  '1dnwIpLiu70',
#  'kqd-9dyR1S8',
#  'T1tyIZOsse0',
#  'OJPb9wboNxA',
#  'M-clPbnRuS8',
#  'fe11axTQ8dc',
#  'gEFsCZBkZ5E',
#  'eQ5DXFvn6Pc',
#  '9OteczRHLbg',
#  'Bzjk7rWL__M',
#  'tchg8LwGFpU',
#  'FoYUYhzKr9s',
#  'Ex3-15peJvA',
#  'xUJeH7Iem8s',
#  'VCNSTWUjvLs',
#  '2cL_JjuqtXU',
#  '4IUctYk14zg',
#  'ZHE80GtZ7DE',
#  'CcMrchJstqc',
#  'bUph6bLNPEA',
#  'BsHcTKhK02M',
#  'rmQXR2tV6CE',
#  'jYwW7KTQecc',
#  'AJduIP8jK58',
#  '2eSvf5UTQLE',
#  '8LpUdn2kEGs',
#  '3gSGJNmiQ0k',
#  'A-nqSfCDWrk',
#  'x53VpCVnpmw',
#  '0MYy4uhyhaY',
#  'QGVfIrN94gI',
#  'QaH8Dkbklco',
#  'nV5kHV_NHbY',
#  'BMxeYWrlNjU',
#  'rWmS-IeLey0',
#  'FVhnwKHB4jQ',
#  'rk2EazytQMY',
#  '8NeoBFE-N4M',
#  '33AabvbQc-4',
#  'BLxcEU-uFY4',
#  '70mMQjNqvAM',
#  'XiGFkIiKoaw',
#  'L6K_1ucJnC4',
#  'llvvNdbsrM0',
#  'RUqfQZvRjaI',
#  'aH-QQkAgBCQ',
#  'r5vM6ezhYVo',
#  'Y3cZgm1yd_A',
#  'gUOnmkxrhXQ',
#  '4ortC_sNzZU',
#  'OKcto3bm0A8',
#  'PW3RhvmtRwM',
#  'OXS8_0oU2Xs',
#  'sWmwaG4xI0Y',
#  'bs-K04kURE8',
#  'FzDEXn-cgAk',
#  'fRtcjnxktok',
#  'WKGktnSghz4',
#  '2_bYAS0HAmU',
#  'gjS6j5W3BqY',
#  'KvcjTkr29sk',
#  'HK_VcRv_XH4',
#  'iac_KXGQ6fU',
#  'AN9iYSIJ4q0',
#  'LbdfutrVVko',
#  'WzFMWTaCVQw',
#  'cq8NbhpmlJI',
#  'Rui2RPx4d_E',
#  'B6mvrxoRhVw',
#  'mcunsS2kzLM',
#  '0WBDWNuLlQE',
#  'Q7LDP_WyduU',
#  'QivDHHG88SU',
#  'eAyifGqG7Cg',
#  'Fv0Gl7Ad95c',
#  'R8FVQPtbEgg',
#  'LpqWp0_97F0',
#  'zC63Vntc0hI',
#  'fabeBcQ_--0',
#  '3_yk2XulFk0',
#  '2WpDR4XkhI4',
#  'iASlonro9og',
#  'D_UiZ-QpiSY',
#  'aEIda656oas',
#  'YdE5NYzcnMc',
#  'T_YB21GYNZQ',
#  'fA2iiGXz68k',
#  'D3yBYDNSMBo',
#  'O8OnKgjyKLI',
#  'txaRLuMkRRk',
#  'LtR8kxeO-Ag',
#  'yOf017HuGTI',
#  'omw_0AiJeF4',
#  'MqJFp57pJJI',
#  'hNE3vwvrr24',
#  'GfW7jwfFLxU',
#  '-IKUL6CYGT4',
#  'cWnt5Znb3MU',
#  'g_ikSIsQ6qk',
#  'ewRkQWdo7K4',
#  'SK0IiDuuiU4',
#  '98C5dkQqkWI',
#  'kEItZXnuu28',
#  'wCja3xV7a38',
#  'lx19OhHzGyg',
#  'C2nRjozK0SM',
#  'eYNTWJc3TM8',
#  'fygk54UIk0o',
#  'Awtia812RZ8',
#  'NxshB7nUFXo',
#  'FVNzUuAuiL8',
#  'osfhvKlhII8',
#  'SuUYKotHIBs',
#  'ezol63alYBM',
#  'pWTVcJHqBEA',
#  'CC0fg80k3DI',
#  'KltdEcHi3yA',
#  'Rvqpze_ismc',
#  'YBUlp9mGoug',
#  'qFs5_bR5kZg',
#  'uEZHzgLu5L4',
#  'FPsrAbSUcW4',
#  'vRmGJtCArTc',
#  'FZM6Q7dupgU',
#  '4bIohpGHSok',
#  '3mt1Sh-EL1M',
#  'aefza-VW7FE',
#  'GL0c17W65J0',
#  'GNESGLfYORQ',
#  'F87YjEBC08w',
#  'SUofAMeD1Ic',
#  '_79lLM3Erno',
#  'uC29uh1zZKw',
#  'VzGFf1-Kigs',
#  'goukIwRloa0',
#  'H0o3PyyQhb8',
#  'vuj6kbN7E_g',
#  'wFbR6BQ9LX8',
#  '8lfdIGbyCWc',
#  'VaFGv-5k8Jk',
#  'd63-6srS3us',
#  'Nw36fIsUcdo',
#  'D-A6tHjNJKk',
#  'qRZjFKGO6Pg',
#  'akfNiJkuJYw',
#  '54qERH872oY',
#  'fBWFqqLUjMQ',
#  'zVcTE41WcsM',
#  'RGHji_Js9Dw',
#  'mc0gYEetNZc',
#  '-RrkBNHTgwY',
#  'eXC4qhoOLnU',
#  'nbqY31F3koY',
#  '-FD9yoQBETE',
#  'G1Trtyy_JYw',
#  'znO8ir5ymMI',
#  '2Et-jnzoL-4',
#  '9xGM8oqmajo',
#  'ipJJ3gvonrM',
#  '-incg04-XUc',
#  'w6nammkPKb8',
#  'x7zQNkyXylM',
#  '-5L4zP-jgew',
#  'dsTmTZguzn8',
#  'hzkBr3ECRUA',
#  'IoJE87bk6p0',
#  'NGBAD2KpCDQ',
#  'aMf8wEXaM-w',
#  'CENDph9K4g0',
#  '6JQrt5tWntc',
#  'eOihKVxOYgM',
#  'qGGVjpXetU0',
#  'gw77xzoFG4w',
#  'Luf1pCVsHz0',
#  'JGsB5DFhmTU',
#  'VtZlqXoQ4Vw',
#  'uJ9XPhEKnfM',
#  'C2LAX0DXpqs',
#  '35G1U3CxgSU',
#  'xdzL0GKeqqM',
#  'LLJpzj4oDXI',
#  'w0pvLjkSKOw',
#  'OGzrVYn_yqE',
#  'RsxYxcLmmIA',
#  'ngz_1AlvCuE',
#  'M1mdGDVidzE',
#  '23VWAi0laJY',
#  'uiVWst0lggc',
#  'SU7x_RUwFKI',
#  'NMw_FQ247wc',
#  'vFIkBH2Pz4g',
#  'q009fxPvY-c',
#  'u-Gx4rMjAUQ',
#  'I2mAxl9pwV0',
#  'QTf_NSk3JhY',
#  'Fve7wxU0YMg',
#  'fNd1lLStTHo',
#  'IL0aIeRFNNI',
#  'rSO_kG15Qjg',
#  'uvMgUHx5Jzk',
#  '9wQnQTcIYCM',
#  'jFaWo9qHypk',
#  'Tb1efYGbKSA',
#  'TI0cu6t99pA',
#  'OrIcTAyCIPA',
#  'SVPwE1p3U2M',
#  'j9UwhmeZupU',
#  'PFwU8Nur0hI',
#  'UY2M5Lt7uaA',
#  'YLHgr1LQYPs',
#  'O2pdfQUtNUs',
#  'Z0E_63GPl_Q',
#  '4EQub4ok0Is',
#  '2TI0YoCJX4U',
#  '9vxknuON1As',
#  'qkb9Hkf3nX8',
#  '5hdyLqc3byI',
#  'x-qJ7SZEj2s',
#  'EaSswCcjM80',
#  'dKQHX-ZL4y8',
#  'Qb4O5cWw9TE',
#  'IFZEx92_JRs',
#  'JBNidMaecRc',
#  'Z5zUdsSuyJk',
#  'AWxOEmP_Tw0',
#  'meTGim_1G7s',
#  'ae8xCAZ-2cU',
#  'M-VWsEvZuwc',
#  'uTLIm64Up5I',
#  'EMQLiB2yMLw',
#  'aVWHlgLL_K0',
#  'a8mVeLbyotw',
#  'tNkOdZvujuo',
#  'LkrjXU4zlD4',
#  'KoOSVTMwixU',
#  'xokCv8Vwgk0',
#  '8FRdhBrMEZs',
#  'DtRJtCbLvBw',
#  'RjZ2w4ydbyI',
#  'QjjHi2zlZBg',
#  'Tr696DkgHm4',
#  '9D8PzYz0xXc',
#  'cIG1zvkbZjU',
#  '03y-cSixCac',
#  'oGbihTrKIXI',
#  'alx1y7J7d6Y',
#  '5ALYqidvGOQ',
#  'YjGpWmPshUc',
#  'dOzj0MEGLow',
#  'pcHONViSOT8',
#  'qrN-pfrmOO4',
#  'Sh2ryM0yQno',
#  'fOOZi68cOxw',
#  'D_X2KOqa9VA',
#  '9fDI9zJcbE8',
#  '5S6qhxedY3U',
#  'vA78yTcpI6M',
#  '22dgBvyjVb4',
#  'xdp1gsQVekQ',
#  '_dJq_xVoHE0',
#  'Zdg7UXSxAEs',
#  'ChyjuxnhkiE',
#  'XGe2J3Kkm-8',
#  'DwRoiF0lCgg',
#  'dgX7Qzk6aqQ',
#  'RtqbTF8d3Mw',
#  'gpoy5lOQeQE',
#  'TpIJZsCUvUU',
#  'E7afilbgTqA',
#  'wWHo5Mcds84',
#  'y8-S0QiVwQs',
#  'M699HY9MZKw',
#  'T0m5SyTuHWs',
#  'DZzYl_WOq38',
#  '8TuPXpsGNho',
#  'VSB4hiW6XoQ',
#  'Xv1_jZDhqEI',
#  '6sPlY_15LXY',
#  'q8-H1nc5-ig',
#  'mr6Brh5d1SE',
#  'i9O9AC2WyxQ',
#  'l54Sm5Pp1Yo',
#  'hBBLJ-pmhNs',
#  'W9Fc9I9sPDE',
#  '3ml_dNuheKc',
#  'ty_PGI8IgpM',
#  'L9w5LU2mN1o',
#  't-KW_-woI30',
#  '5jaOxx3iEu4',
#  'pfKyUJK_frk',
#  'v37VAA75SX8',
#  'r4L6naEjmFM',
#  'csCdw7Mj6x0',
#  'X8XKpJ4j_c8',
#  'T2RBX534HHQ',
#  'GHZXGaht40g',
#  'ysU6TJleS-8',
#  'zMEcHM83f2E',
#  'HWmdzstQIQA',
#  'MxyVIaoOaTg',
#  'yl_FRBUVWgc',
#  'LWyUcHvjgmA',
#  'VpUhl5dBmHQ',
#  '041Ka7q14l4',
#  'WzryaLaWY3Y',
#  'DfEbbq76Mz8',
#  'TlS5u6ojLek',
#  '7F4bdlogmmM',
#  'tsC4S2zgc4A',
#  '7B3pCMHs1Do',
#  'KgdM8njnShc',
#  'InUsctmsrkk',
#  'b_CDPrHiUL0',
#  'uxgpAOfvOj0',
#  'gWwGq-nsXTY',
#  'MBWopK0ZCCw',
#  'xMWzjsZMz3I',
#  'S35kM0NSwC8',
#  '62WZOO_0jLo',
#  'AuLPPl05_Ew',
#  'WPxZOcASa3M',
#  'ZyNUlXfGQ1U',
#  'WKLbUuPGLx4',
#  'lrjeK_Bwa2A',
#  'iCcn9-hoXGk',
#  '1x2djGeYxhI',
#  'aCRL2xoISok',
#  '_1j2Zy8mj-Q',
#  'tSNyUIKACQU',
#  'MWhtD1gKntQ',
#  'idZePzexiB4',
#  'zZvPrss0x3k',
#  'KWiEJtp4JoU',
#  'knGTiNnThEE',
#  'K1tHZpoJiDk',
#  '3AU7LmDHr8k',
#  'ghkMKMhk3TE',
#  'BQvq4cPtaEE',
#  'QGrxUnEY6hE',
#  'vQKp-5JrVXo',
#  'WyfSbWZOoKY',
#  'w9oaZ_WGTE0',
#  'LOXR1Tb-LSk',
#  'ntFPxi8Rwsg',
#  '6g0mz9zGpWs',
#  'koTkj7M0ZRs',
#  'ljeYEEUU5uc',
#  '4KWqOHMxAIc',
#  'rE9Llx_AZL8',
#  'JDEP2oqZvGo',
#  '7uIIgck93rQ',
#  '9sOtdkVFNYA',
#  'TuArg7-QnAI',
#  'HHEdwE1bRNg',
#  'BRnJq7TeXOU',
#  't4y37Rn59SA',
#  'nUpPnPsaoMA',
#  '-qdUe6zZ_RY',
#  '8v_MBHNu1-E',
#  'HOR3IRBbb2I',
#  'vNEholOEqOk',
#  'E5iXZI53PPU',
#  'inpUQiseAPA',
#  '-dYAxboWLdE',
#  'jvABX-54vd0',
#  'ND2u53bRjUA',
#  'xeXJ2bFSQTs',
#  'AXx2HPQEfhA',
#  'JRr6JNqsf0M',
#  'iJWduHwPzg4',
#  'TAiqkCag8O8',
#  'WwJ8MiMKPwk',
#  'MLFyY4fUOhs',
#  'q5tlNIVo_dc',
#  'YISnEnNM3ts',
#  'AGBJf9dbxfQ',
#  'eMSikefzuCI',
#  'jK74JguZ5Yg',
#  '3oRz5PXpzu0',
#  'i3wxWz5xIqI',
#  'If1rhHBnOgo',
#  'P-zDs0X_Szg',
#  'l9a_0QGoTD8',
#  'L1YHio-zDLk',
#  'E4se1C8JdPQ',
#  '0UIo69V3qqI',
#  'Jwx22vlDXeM',
#  'N8lszz1eJH0',
#  'a7vuIoMIZDk',
#  'icGuPwRpQ88',
#  'F-9Utw1atJI',
#  'QiS-X5XCtQA',
#  'vGhww8NNzkc',
#  'VHk3NAWxZKs',
#  'L-L7OjYZWgg',
#  'MqTrVmivdJo',
#  'JRddIwZavwc',
#  'EYNNdzPJCwA',
#  '2Flplhojd5c',
#  'BcA9F2KzYxo',
#  'Mz67r0NjwNg',
#  '57MWar_Uo64',
#  'd7DjvAp2rAQ',
#  'JWRJDzc1B6w',
#  'NYE_V3AF0-A',
#  'nQvpJqvCMC0',
#  'NBivPDHZzNY',
#  'YmQ0EtumVG4',
#  'CwJc22Jt0wE',
#  'yWrb2a6I5FY',
#  'A015FRlTCgo',
#  'f8aPKIlYI7E',
#  '3YhHgbZfCUE',
#  'PMuPrxetgBw',
#  'IDWZtpGYnTs',
#  'I1tMxVh38CQ',
#  'TJCguVgiE3c',
#  'EyroYldNprs',
#  'mdXcVCbdlps',
#  '_UgMWl2wnj0',
#  'eVE9FjbXf6w',
#  'xakokMKl8ZA',
#  'J-dTqyP42iw',
#  'KmtwCVu_yYo',
#  'yO33v1l8BQM',
#  'B-XVY4xrxLU',
#  'QcgsOnC1-bk',
#  'kpTthwzLDbY',
#  'MsjcG8dk0r4',
#  '20GV0p8Jp3o',
#  'k1o5guK-oOk',
#  'p_W3l1mEmZI',
#  '_tPJPGFdIsg',
#  'eTbZVTpjVho',
#  '2Tpqur98T08',
#  'jlfp6tMREY0',
#  'aC_RaI4OCu4',
#  'gXCaDOFOaGA',
#  't2OG_wdt90Q',
#  'RsGWHc1guwA',
#  'zNOmX2jynAw',
#  'O-ZQkWwiWcE',
#  'ydUa2d7zBwI',
#  'VsZGwtfOOIQ',
#  'tkzxC9EHX1g',
#  'MPNjTXXFwRk',
#  'og90urNqCPc',
#  '97sQTV5Mh7Q',
#  'XnsgG4VW3Qs',
#  'uk0-wgXveQc',
#  'm3sVzi2--2c',
#  'qoBCP8IGrRk',
#  '1VlRjJI97PY',
#  'Fa7MY9mWivc',
#  'Mn0Zo-aRFn8',
#  'Cj-8Jxvva9U',
#  'wk_COtgTZW4',
#  'hFPaVUronR8',
#  'L0kMg95yw08',
#  'Jfa2LSEV9n8',
#  'rpT2LGkMF44',
#  'O0OiEobMbAw',
#  'VnvhMoCPgmo',
#  'dKHhW4_4euU',
#  'dCUkdbo-MD0',
#  'UZTdzFl-Kig',
#  'vmq2Jg0cQc0',
#  '_ihRBPRsH54',
#  'GTFkCsCb5RA',
#  'pMjeNVwfJDo',
#  'nL-PWbxCy2w',
#  'oC15guHOYMA',
#  'FT15KopVRac',
#  'uOHQex5vvD0',
#  'vToS1pOhysg',
#  '_ZHA-kHYGgo',
#  '8--GdnW3jJA',
#  'opnERBAhg5A',
#  'Lr_BzqtUlJM',
#  'nC60FG72Oxw',
#  'F3lLh6GJKxM',
#  '6tafIANonXI',
#  'SzVaT8MQTAs',
#  '6Bvgk7Zm93o',
#  'Rju1v21x1Gs',
#  '0RrxHarFw74',
#  '6QqgprGgl0A',
#  '-PhMnLCofJk',
#  'HmPv3kwWymw',
#  'QLpfZDARCBE',
#  'sTPVSWBH79g',
#  '_TB2A4w2I04',
#  '19ND6suzfKA',
#  'gQkDfJC-ObM',
#  '6WRc9PNSJ5s',
#  'EhQonq7fV44',
#  'z4m6R3McvZg',
#  'HfmTbpIkGR8',
#  'psAXk74goRI',
#  'pMm_KQiiTN0',
#  'KlBE7MZVP9o',
#  'rk9UUSpaXW0',
#  'YxGXhtCljyQ',
#  'WeNFrmR-TrU',
#  '67IL7Y1Bg5o',
#  'Rl2mF6AA0yI',
#  '4dhyBIkSKhs',
#  'siQ7ARYU3mQ',
#  '9ElWc3bGMwM',
#  'Rq-6ky-yrWA',
#  'jB0_LdPHAuM',
#  'dGpRwSOni_s',
#  'JutglwSHFXA',
#  'BbqePl7bByk',
#  '9LLyXW7QOVE',
#  'Anlt1Wu8L4Q',
#  'yhewh24JZOY',
#  'u_K8sgAbNFE',
#  'IiLylmXBEvU',
#  '-2JhxZ848ns',
#  'L3ZN-6TV-cs',
#  'tEja50tNnHI',
#  'kVMXbOk_4hI',
#  'WhweVViFuy0',
#  '3W6Xdhgbw0Q',
#  '-71Bmu3ubvE',
#  'F_6GjHvszxM',
#  'dMHOywA0mWo',
#  'QAMRlnS6JCk',
#  'c_1OnwZ7im0',
#  '39it4AFqRKQ',
#  'yh0G8QYlyIw',
#  'n1kHzRkJFaw',
#  '8ejZDrLrMEo',
#  'bEmTKuqa66Q',
#  '_Hn1UyHMkpA',
#  'zSp7aMVBl_8',
#  'uhBLvpb0-nU',
#  'VHsYGKoObGk',
#  'LsoEjmzAyzo',
#  'o2OLfOeuam8',
#  'LXUBbnKy1Xw',
#  'Ttw7BW4zCwA',
#  'arc2gpVX70s',
#  'N8VY6oCQWyw',
#  'AfSnDaA53N8',
#  'U8rDjO_yVlU',
#  'l9WpoBjrCoQ',
#  'HXV8jGjYk3M',
#  'OxLwJQR_35c',
#  'JceqvFUrUxM',
#  'xFKiwhEOZCM',
#  '_oqtEF69p5U',
#  'vI-t1-r-otA',
#  '0hoSasTwYPg',
#  'B6iX7Odo9G8',
#  '-x04uu4zJwc',
#  '6fnYhwuyF9A',
#  '1x9YE6ML1Qg',
#  '9Dp0L8jtDI4',
#  'g8gRktibb7I',
#  'N5vT5c8r8n4',
#  'Bwno_ghrfjA',
#  'F9FZouzHMLA',
#  '-w3rxcBSoT8',
#  'Gkig_5tbZUo',
#  '2HuVbRvRtXo',
#  '-1G0tpbD5no',
#  'V-Uf7aNJBhQ',
#  'xQ0MLf1GdEo',
#  '0RF7Bnyfso4',
#  'PkxhBNBxPVI',
#  'HK61iVnepZ4',
#  'Yuc6-zLfy1k',
#  'aevFdSEigEU',
#  'pgPk2m53UzA',
#  'rnmMJ6THC58',
#  'y5K-xQnfRy8',
#  'PKormp-7ovM',
#  '5G27R59UUCI',
#  'zat9eLWarPQ',
#  'XUOQcoGwVYc',
#  'uzZmrVX9T9g',
#  'aCO_UlhxjoM',
#  '1nqSxDzDGCQ',
#  'QI9JNXlbf5o',
#  'yWFPcvHKjLE',
#  'bUBIlvo6Y3c',
#  'q8Ldd3kxQUA',
#  'vPA86nXr550',
#  'csaupm4kly0',
#  'ZHuMhhn1i0E',
#  'mVDQoG8VkPE',
#  'gwlDOpPAolI',
#  'Xk0fMcEgLPc',
#  'teoTT9WgkoA',
#  'cY-7Sy1EBYk',
#  'Uo9cqWnN0y0',
#  'LcOcfHPGAr8',
#  'mQrIjI0HS78',
#  'Bu-5mzLvCiM',
#  'yX09TP1mSOU',
#  'WQWeyn6ZlgI',
#  'ZHg83lMPTCM',
#  'Fzi4mvZ22oA',
#  'ky9kVVsKdMw',
#  '-kJPWnZHy-0',
#  'IUucYVzy_hs',
#  'HTIqcTVCRds',
#  'xMtpPG2U1Zg',
#  'UkKqjcXbRqA',
#  'VKBlcaLUwW8',
#  'poe9cBcioRM',
#  'rbNKMx6Jul8',
#  'x8OiNcxlku0',
#  '6aujXYZwrus',
#  '-IvmkvwktHY',
#  'Iem3fQ6VdcM',
#  'Wvz1IcsWREQ',
#  'oTQ8cT_6-9s',
#  '491VXG8flcY',
#  '9XHwSsqZEL4',
#  '1ibSXtGx_z4',
#  'f9rZESKbT0Q',
#  'enxdpdi7uqI',
#  'dWllSDYZyRA',
#  '4dvLZnfg8L0',
#  'XRecW7E1PRM',
#  '0J7Zfq8lI2Q',
#  'MDgO361HiQc',
#  'i3h0A41KDts',
#  'o49gLje2WzM',
#  'PxFKQvkm8EY',
#  'sK7fv1wos1g',
#  'kM9t0Q5RquA',
#  'IVI88BVwCTQ',
#  'TbdFXD_NxFQ',
#  'xI00SNxuSAw',
#  '5bXQk0bDzyE',
#  'jxEhwGq-Cvs',
#  'g2nJkbNhmSY',
#  'bv6VYKYPxH8',
#  '0CmRVaKoZ-E',
#  '4M5gMtE4rMg',
#  '_c7SVNgHpdY',
#  'VolCrFwCq4Q',
#  'PeSUPOJ9bUs',
#  'deR-gwikNwA',
#  'OG0mQ5TAKn0',
#  'nfE7fL0avbI',
#  'hzourDbJIgU',
#  'd8rlDVYSSMc',
#  'AisOtjs80nM',
#  'v5ONdOrVvr4',
#  't73PcfmNcmE',
#  'bTrvUII1fbQ',
#  't72z5P1sJtY',
#  'gX85WiWBI-E',
#  'sM7YnFDzGfU',
#  'LSQK2lCiaVw',
#  '7RJ_2PlLiF4',
#  'Efe24zYhwbA',
#  'J5xGRiGsVXQ',
#  'I12sy4vudH0',
#  'nVcsqi9rt1U',
#  'Qee9-yvNqkU',
#  '2MkUr8JGZbA',
#  'ITxzhqPxaZ8',
#  '58ZKu6l1Cyo',
#  'UobbvRA5AIw',
#  'cX47J5Jcu-4',
#  'C4Xn9GW3nDk',
#  'aU-YFpUeRMY',
#  'c7A5cHM84fU',
#  'PBZ8MwlgO6Q',
#  'iynWDzsXHIs',
#  'UMWt_yac0Rk',
#  'lGy0_uYuZTE',
#  'k9xaGpPX5HM',
#  'hD8sfosyBVQ',
#  '2Ml89t6PH-E',
#  'UNH_l9l1xIs',
#  'W47KrA_GCJY',
#  'YYHUbn8oKnU',
#  'LPB32zY6SLg',
#  'yht3kKsDOpg',
#  'UGVt-h7y6V4',
#  'lozFAl0TB9w',
#  'qKdrk4PJ4dM',
#  'PkDqdQ6ognI',
#  'XgUfV2Cf41M',
#  '0gUaHaUTyZs',
#  '1AGfqMdDhbo',
#  'ZsJCehnPnag',
#  '_hkJ2Y1I00k',
#  'Y-_lgzXfrCM',
#  'HEjQ1Ci0NHQ',
#  'iIIZ7Tx58RM',
#  'USMiCrR5BdQ',
#  'BUmCWRe30gY',
#  'f6jnTEWbl2A',
#  'rRnWlSLBYZU',
#  '8hkH41M5Azc',
#  '8ISeZwcJRvI',
#  'TylbBl65Dgw',
#  'pJZ5mRbz9VU',
#  'suQ06jk56fY',
#  'Yw_WpZWl7mA',
#  '3uWcLXq32Es',
#  'uDJlNeyCKPg',
#  'clsfjAJSqHI',
#  'vvuLEsBcuVU',
#  'vk6Mopzo6LA',
#  '6jhUNtNpuEs',
#  'TZ9KVbQ8ZrE',
#  'AHZNFtAXyJI',
#  'PbF963e_z9U',
#  '3PofZs86GsM',
#  'Qm-9RwGTP9Y',
#  'fJnzARA6KcA',
#  'wU9GC_4Qb1E',
#  'btHFIQaFuXU',
#  'Skhsjta-x_k',
#  'f2ytTuaWmLU',
#  'LHCoE3Az7QY',
#  'aKRRJqd-nFY',
#  '9ucSQA2TSCs',
#  '6Bm0idHQHBQ',
#  'g9oh3DVAKCs',
#  'BEHX32zXLw0',
#  '32evb0XGv44',
#  '9one6d1wCd8',
#  'yObhEdl5vpQ',
#  'iIlAVK6ZBF0',
#  'EyQSGozp3oE',
#  'nn2r_1NPwf4',
#  'f-vaXqiAVfc',
#  'cD6WmuOejVM',
#  'ivnQCTq8maw',
#  'DbVdz2nsU-E',
#  'd94fu08BOmk',
#  '7OozFu4XKf4',
#  '8Q6RG-4flOA',
#  'qUrp1JdlMrs',
#  '7Ple9AP_-gc',
#  '2OPeSsMcu8k',
#  'vqKQoF3yRoI',
#  'DqCFDzQnk_o',
#  'HiZrhOJbk7M',
#  'dXFuFRBvb5U',
#  'NTBtLyp1-qY',
#  '6op4TfGw-KU',
#  'o1ErQAcqafQ',
#  'K74DTdrxv4I',
#  'xU_PlWOZHoo',
#  'VwzNNqQ9f6Q',
#  'LcBFUHPUq40',
#  'mfo-hs-NKlw',
#  'uazbPaM9NDQ',
#  '3P22r5wyIRA',
#  'nkvZlVimnxA',
#  '_HLklpt1aH0',
#  'h2IKcMMXwQ0',
#  'fYirTjM9YlE',
#  'NNy-ohYV4RI',
#  'Lsg10hx5W08',
#  'vS5UgWCOr6w',
#  'tyThUncm4cc',
#  'rNjUcL06pGY',
#  'b8MA5F3mwu4',
#  'X-It8N8oUkM',
#  'x2mjPsH4vdc',
#  'BlK2Oa2I6cE',
#  'v7YOHtezzjI',
#  'WOgxWSj-InU',
#  '8ha2Y-XLphI',
#  'lPzAfEVFhro',
#  'ZRbbaoSpL34',
#  '85UvtkiTAh8',
#  'FSgPWTZHB18',
#  'tBTItbut7zE',
#  'nUlXSkdU41o',
#  'kMaZHr2iAt0',
#  'NJfEyK_4k7c',
#  'HPTTocYriSQ',
#  'eefrttKeO3E',
#  '0S03ez26l-g',
#  'Icdgh0vArsI',
#  'L0wrF6sSfjA',
#  'VxgC4ivPG3Q',
#  'WR5IeXbH7kA',
#  'RgU5wHE-0p8',
#  '1VQF1kWuW_g',
#  '472ef2Yp0Vw',
#  '86luuMl8__0',
#  'PQ8xD7L6dTU',
#  'crWAt3L18CU',
#  'pM4_KIGq8iw',
#  'RNIACPBQ_AE',
#  'nCH0Uf-fG4M',
#  '-ksi4vPsX3M',
#  'ns42Mf8GyJM',
#  'mE0JWOI7EyM',
#  'qS1Czkamw5M',
#  'xocE2COD8tU',
#  'FSoBmSylNcQ',
#  'C734pmuo43Q',
#  'HRy69qRlMuw',
#  'hcjds5H_vMo',
#  'ZWRYKa8WPHo',
#  'bWLi1Mwa44E',
#  '91_8HFL1wlg',
#  '3IUpS8Nn2Vw',
#  'k5zTMdninV4',
#  'ECdQFWK5ChE',
#  'dfcytwXlnOk',
#  'TeA2Tr4EsOM',
#  '651P_gFA3AQ',
#  'b8j9ZmL510s',
#  'kO29CLON8rw',
#  'cnzFTmQZxSU',
#  'nRy-Ervwr-I',
#  'pJhzpYM_Z5I',
#  '4rMos-pnZUA',
#  'ReyazJXuin0',
#  'FWkfZ7GobtY',
#  'dwUj_NRagfY',
#  'VE4UJmkZd8s',
#  '7Op4a2uToVA',
#  'QGbPmbDESDs',
#  'jRlC8jAucic',
#  'OQjLWQzz3mg',
#  'HqFFVkPVyVs',
#  '_WaejmS8cHs',
#  '2nIdE0DB5jM',
#  'sF-qu0OiSSg',
#  'sx2TRy6v62k',
#  'jO_2VEzwrcQ',
#  '-2cEgLzepV0',
#  'Qstpp9g1PYs',
#  '3dioiW6lBaA',
#  '9z2xef_cyc0',
#  'Mh1siaUythc',
#  'H7yJ44pIfHo',
#  'ZWELfq0Zn0s',
#  'tkNanb8QOAM',
#  'kTaLGuZ0mQs',
#  '9nXZv3-NjxE',
#  'etLX7IL9lmQ',
#  '06RqU21mnZo',
#  'EzmdOdmDjHw',
#  'h0ai4SVYv9o',
#  '5MGlqeOzlpw',
#  'Yc24GOXR7E4',
#  '_nWBSTaHgDs',
#  'QNCqOq2lrlY',
#  '3Dn7qGQmYfw',
#  '1USI_R1ZQIY',
#  'vIRTpaMsg28',
#  '_DB194LsTlg',
#  'RWdNhYSxe9Q',
#  'FiJuDYVl2vo',
#  'RoQyl8zubUc',
#  'BzwCsULB57I',
#  '9laufsJ5NFo',
#  'bqyBaL7oaiI',
#  '5D8mOywKndc',
#  'RziSv-EysBE',
#  'tUwztkUaOlg',
#  'rTDFkPgS-Jw',
#  'f5y22O4UWmQ',
#  'Kd0SdC3q7vM',
#  'n4Z1NWeMz-A',
#  'my1sOngML4c',
#  'weCSN6wT5ZA',
#  'r03ogju9qUQ',
#  'H_VgS1oiV7s',
#  'npmvbK-PjlM',
#  'gfH_ocv40is',
#  'KWZ2QmkM3F0',
#  'PBiqvWlr4MU',
#  'm-gBcoypeOI',
#  'mmHej9eFgzw',
#  'YbkDLwbR6XA',
#  '-y95pKZR5X8',
#  'GGOa8YaNWCM',
#  '9iIStDw9UrQ',
#  'NWoPIzRXA6g',
#  'WOYEXZEuzbo',
#  'CRjj9deDufI',
#  '8k9OFGw7SP0',
#  '2OpGNjTtMPQ',
#  'cOIQepwREI8',
#  'FaPZPgJhv-g',
#  '2SrKd56HYV8',
#  'Idh3nLfN_1c',
#  '4ZUbbjde368',
#  'pYyAWwyr0MI',
#  'SS7xp_UeUxY',
#  'fqATA9tuUM0',
#  'smQv6pX8xyA',
#  ...]

# %%
def get_video_details(youtube,video_ids):
    for i in range(0, len(video_ids),50):
       request = youtube.videos().list(
          part = 'snippet,statistics',
          id =','.join(video_ids[i:i+50]))
    
       response = request.execute()
       all_video_stats=[]
       for video in response['items']:
           video_stats = dict(Title =video['snippet']['title'],
                              Published_date = video['snippet']['publishedAt'],
                              Views = video['statistics']['viewCount'],
                              #Likes = video['statistics']['likeCount'],
                              #comments = video['statistics']['commentCount']
                    )
           all_video_stats.append(video_stats)

    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_details
# Out:
# [{'Title': 'अमेरिकेला शह देण्यासाठी जळगावची उभारणी झाली | jalgaon | maharashtra',
#   'Published_date': '2021-07-19T12:38:10Z',
#   'Views': '87413'},
#  {'Title': 'Rekha आणि Smita Patil यांच्यात शेवटपर्यन्त मैत्री झाली नाही I Bol Bhidu',
#   'Published_date': '2021-07-19T07:27:59Z',
#   'Views': '7467'},
#  {'Title': 'santoshi mata या सिनेमामुळे sholay सिनेमा फ्लॉप होण्याची वेळ आली होती | cinema | santoshi mata',
#   'Published_date': '2021-07-17T15:29:47Z',
#   'Views': '3880'},
#  {'Title': 'barshi येथील cancer hospital सुनिल दत्त यांनी उभारलं आहे',
#   'Published_date': '2021-07-17T12:57:24Z',
#   'Views': '19585'},
#  {'Title': 'कोण होत्या इंदिरा गांधींना नडणाऱ्या “पाणीवाली बाई”..? Mrunal Gore | Maharashtra',
#   'Published_date': '2021-07-17T09:20:11Z',
#   'Views': '3052'},
#  {'Title': 'Balasaheb thackeray यांच्या विरोधात Arun Gawali का गेला होता ? | BolBhidu | Arun gawli And Balasaheb',
#   'Published_date': '2021-07-16T15:29:48Z',
#   'Views': '219849'},
#  {'Title': 'Ajay Devgan आणि kajol .यांच लग्न दोन मिनटात पार पडलं | cinema | bollywood',
#   'Published_date': '2021-07-16T12:29:17Z',
#   'Views': '4972'},
#  {'Title': 'baburao adaskar या बीडच्या आमदारांच्या मिशीचा मुका रशियन मुलीने घेतला होता',
#   'Published_date': '2021-07-16T07:41:04Z',
#   'Views': '9933'},
#  {'Title': 'या कारणांमुळे लोकसंख्या नियंत्रण कायद्याला विरोध होतोय | YogiAdityanath | UP',
#   'Published_date': '2021-07-15T16:04:48Z',
#   'Views': '1163'},
#  {'Title': 'शाहू महाराजांच्या घसरगुंडीची सत्यकथा | Shahu Maharaj | Kolhapur',
#   'Published_date': '2021-07-15T12:35:13Z',
#   'Views': '868713'},
#  {'Title': 'या व्यक्तीने वडापावचा शोध लावला | VadaPav | Mumbai',
#   'Published_date': '2021-07-15T08:57:34Z',
#   'Views': '209562'},
#  {'Title': 'पवारांचा राष्ट्रपती होण्याचा मार्ग ओरिसातून | SharadPawar | President',
#   'Published_date': '2021-07-14T15:15:58Z',
#   'Views': '5222'},
#  {'Title': 'नो "ब्रा" चळवळ काय आहे | NoBra',
#   'Published_date': '2021-07-14T12:42:02Z',
#   'Views': '124512'},
#  {'Title': 'धिरूभाईंनी जोरात फिल्डींग लावली, पण समोर प्रामाणिक मुख्यमंत्री होते | ShankarraoChavan | Ambani',
#   'Published_date': '2021-07-14T07:13:17Z',
#   'Views': '79123'},
#  {'Title': 'हाजी मस्तान कसा झाला मुंबईचा डॉन | HajhiMastan | Mumbai',
#   'Published_date': '2021-07-13T15:37:00Z',
#   'Views': '57777'},
#  {'Title': 'उज्ज्वल निकम हा पवारांचा माणूस आहे | Ujaval Nikam | Sharad Pawar | Bal Thackeray',
#   'Published_date': '2021-07-13T12:24:41Z',
#   'Views': '73445'},
#  {'Title': 'भागवत कराडांसाठी गोपीनाथ मुंडेंनी आपली प्रतिष्ठा पणाला लावली होती | GopinathMunde | PankajaMunde |',
#   'Published_date': '2021-07-12T14:32:16Z',
#   'Views': '10712'},
#  {'Title': 'अन् मायकल जॅक्सन तर बप्पी लहरींचा फॅन निघाला | BappiLahiri | Michael Jackson',
#   'Published_date': '2021-07-12T12:41:37Z',
#   'Views': '5054'},
#  {'Title': 'भारतीयांच्या हातात आलेलं पहिलं रॉकेट RX100 ; पहा RX100 चा संपूर्ण इतिहास | YAMAHA | BIKE | RX100',
#   'Published_date': '2021-07-12T07:34:19Z',
#   'Views': '157270'},
#  {'Title': 'फक्त तीन तासात अशोक सराफ मराठीचे सुपरस्टार झाले | Ashok Saraf | Marathi Film | Dada Kondake',
#   'Published_date': '2021-07-10T13:29:20Z',
#   'Views': '12783'},
#  {'Title': 'ती खेळी सुनिल गावसकरांच्या आयुष्यातली सर्वात खराब खेळी ठरली | SunilGavaskar | Cricket',
#   'Published_date': '2021-07-10T04:16:02Z',
#   'Views': '1553'},
#  {'Title': 'बाळासाहेबांनी एका फोनवर शाहरूख खानचा माज उतरवला होता | BalasahebThackeray | SharukhKhan',
#   'Published_date': '2021-07-09T13:10:55Z',
#   'Views': '1262462'},
#  {'Title': 'ते नसते तर औरंगाबाद आजही एक मोठ्ठं खेडच असत | RafiqZhakeria | Aurangabad',
#   'Published_date': '2021-07-09T04:10:15Z',
#   'Views': '3700'},
#  {'Title': 'महाराष्ट्राच्या आर्थिक नाड्या आत्ता सहकारमंत्री अमित शहांच्या हातात | Amit Shah | Maharashtra',
#   'Published_date': '2021-07-08T15:05:23Z',
#   'Views': '1878'},
#  {'Title': 'मुख्यमंत्री करतो म्हणून नारायण राणेंना ४ वेळा गंडवण्यात आलं होतं | Nayrayan Rane | ChiefMinister',
#   'Published_date': '2021-07-08T04:30:11Z',
#   'Views': '12011'},
#  {'Title': 'One To One | Arvind Jagtap With Sanjay Raut |  संजय राऊत यांची दिलखुलास मुलाखत',
#   'Published_date': '2021-03-20T06:25:44Z',
#   'Views': '19861'},
#  {'Title': 'One To One | Promo | Arvind Jagtap With Sanjay Raut | संजय राऊत यांची दिलखुलास मुलाखत | Bol Bhidu',
#   'Published_date': '2021-03-16T11:26:37Z',
#   'Views': '14814'},
#  {'Title': 'मकरंद अनासपुरेची धमाल. नक्की ऐका #bolbhidu #makrandanaspure #pune',
#   'Published_date': '2019-08-21T15:26:52Z',
#   'Views': '5338'}]

# %%
df_Video_Details = pd.DataFrame(video_details)

# %%
df_Video_Details
# Out:
#                                                 Title        Published_date  \
# 0   अमेरिकेला शह देण्यासाठी जळगावची उभारणी झाली | ...  2021-07-19T12:38:10Z
# 1   Rekha आणि Smita Patil यांच्यात शेवटपर्यन्त मैत...  2021-07-19T07:27:59Z
# 2   santoshi mata या सिनेमामुळे sholay सिनेमा फ्लॉ...  2021-07-17T15:29:47Z
# 3   barshi येथील cancer hospital सुनिल दत्त यांनी ...  2021-07-17T12:57:24Z
# 4   कोण होत्या इंदिरा गांधींना नडणाऱ्या “पाणीवाली ...  2021-07-17T09:20:11Z
# 5   Balasaheb thackeray यांच्या विरोधात Arun Gawal...  2021-07-16T15:29:48Z
# 6   Ajay Devgan आणि kajol .यांच लग्न दोन मिनटात पा...  2021-07-16T12:29:17Z
# 7   baburao adaskar या बीडच्या आमदारांच्या मिशीचा ...  2021-07-16T07:41:04Z
# 8   या कारणांमुळे लोकसंख्या नियंत्रण कायद्याला विर...  2021-07-15T16:04:48Z
# 9   शाहू महाराजांच्या घसरगुंडीची सत्यकथा | Shahu M...  2021-07-15T12:35:13Z
# 10  या व्यक्तीने वडापावचा शोध लावला | VadaPav | Mu...  2021-07-15T08:57:34Z
# 11  पवारांचा राष्ट्रपती होण्याचा मार्ग ओरिसातून | ...  2021-07-14T15:15:58Z
# 12                     नो "ब्रा" चळवळ काय आहे | NoBra  2021-07-14T12:42:02Z
# 13  धिरूभाईंनी जोरात फिल्डींग लावली, पण समोर प्राम...  2021-07-14T07:13:17Z
# 14  हाजी मस्तान कसा झाला मुंबईचा डॉन | HajhiMastan...  2021-07-13T15:37:00Z
# 15  उज्ज्वल निकम हा पवारांचा माणूस आहे | Ujaval Ni...  2021-07-13T12:24:41Z
# 16  भागवत कराडांसाठी गोपीनाथ मुंडेंनी आपली प्रतिष्...  2021-07-12T14:32:16Z
# 17  अन् मायकल जॅक्सन तर बप्पी लहरींचा फॅन निघाला |...  2021-07-12T12:41:37Z
# 18  भारतीयांच्या हातात आलेलं पहिलं रॉकेट RX100 ; प...  2021-07-12T07:34:19Z
# 19  फक्त तीन तासात अशोक सराफ मराठीचे सुपरस्टार झाल...  2021-07-10T13:29:20Z
# 20  ती खेळी सुनिल गावसकरांच्या आयुष्यातली सर्वात ख...  2021-07-10T04:16:02Z
# 21  बाळासाहेबांनी एका फोनवर शाहरूख खानचा माज उतरवल...  2021-07-09T13:10:55Z
# 22  ते नसते तर औरंगाबाद आजही एक मोठ्ठं खेडच असत | ...  2021-07-09T04:10:15Z
# 23  महाराष्ट्राच्या आर्थिक नाड्या आत्ता सहकारमंत्र...  2021-07-08T15:05:23Z
# 24  मुख्यमंत्री करतो म्हणून नारायण राणेंना ४ वेळा ...  2021-07-08T04:30:11Z
# 25  One To One | Arvind Jagtap With Sanjay Raut | ...  2021-03-20T06:25:44Z
# 26  One To One | Promo | Arvind Jagtap With Sanjay...  2021-03-16T11:26:37Z
# 27  मकरंद अनासपुरेची धमाल. नक्की ऐका #bolbhidu #ma...  2019-08-21T15:26:52Z
#
#       Views
# 0     87413
# 1      7467
# 2      3880
# 3     19585
# 4      3052
# 5    219849
# 6      4972
# 7      9933
# 8      1163
# 9    868713
# 10   209562
# 11     5222
# 12   124512
# 13    79123
# 14    57777
# 15    73445
# 16    10712
# 17     5054
# 18   157270
# 19    12783
# 20     1553
# 21  1262462
# 22     3700
# 23     1878
# 24    12011
# 25    19861
# 26    14814
# 27     5338

# %%
df_Video_Details.dtypes
# Out:
# Title             object
# Published_date    object
# Views             object
# dtype: object

# %%
df_Video_Details['Views'] = pd.to_numeric(df_Video_Details['Views'])

# %%
df_Video_Details.dtypes
# Out:
# Title             object
# Published_date    object
# Views              int64
# dtype: object

# %%
df_Video_Details['Published_date'] = pd.to_datetime(df_Video_Details['Published_date']).dt.date

# %%
top_10_video = df_Video_Details.sort_values(by='Views',ascending=False).head(10)
top_10_video
# Out:
#                                                 Title Published_date    Views
# 21  बाळासाहेबांनी एका फोनवर शाहरूख खानचा माज उतरवल...     2021-07-09  1262462
# 9   शाहू महाराजांच्या घसरगुंडीची सत्यकथा | Shahu M...     2021-07-15   868713
# 5   Balasaheb thackeray यांच्या विरोधात Arun Gawal...     2021-07-16   219849
# 10  या व्यक्तीने वडापावचा शोध लावला | VadaPav | Mu...     2021-07-15   209562
# 18  भारतीयांच्या हातात आलेलं पहिलं रॉकेट RX100 ; प...     2021-07-12   157270
# 12                     नो "ब्रा" चळवळ काय आहे | NoBra     2021-07-14   124512
# 0   अमेरिकेला शह देण्यासाठी जळगावची उभारणी झाली | ...     2021-07-19    87413
# 13  धिरूभाईंनी जोरात फिल्डींग लावली, पण समोर प्राम...     2021-07-14    79123
# 15  उज्ज्वल निकम हा पवारांचा माणूस आहे | Ujaval Ni...     2021-07-13    73445
# 14  हाजी मस्तान कसा झाला मुंबईचा डॉन | HajhiMastan...     2021-07-13    57777

# %%
sns.set(rc={'figure.figsize':(6,8)})
ax=sns.barplot(x='Views',y='Title',data=top_10_video)
# Out:
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2348 (\N{DEVANAGARI LETTER BA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Matplotlib currently does not support Devanagari natively.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2366 (\N{DEVANAGARI VOWEL SIGN AA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2355 (\N{DEVANAGARI LETTER LLA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2360 (\N{DEVANAGARI LETTER SA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2361 (\N{DEVANAGARI LETTER HA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2375 (\N{DEVANAGARI VOWEL SIGN E}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2306 (\N{DEVANAGARI SIGN ANUSVARA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2344 (\N{DEVANAGARI LETTER NA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2368 (\N{DEVANAGARI VOWEL SIGN II}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2319 (\N{DEVANAGARI LETTER E}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2325 (\N{DEVANAGARI LETTER KA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2347 (\N{DEVANAGARI LETTER PHA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2379 (\N{DEVANAGARI VOWEL SIGN O}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2357 (\N{DEVANAGARI LETTER VA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2358 (\N{DEVANAGARI LETTER SHA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2370 (\N{DEVANAGARI VOWEL SIGN UU}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2326 (\N{DEVANAGARI LETTER KHA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2330 (\N{DEVANAGARI LETTER CA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2350 (\N{DEVANAGARI LETTER MA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2332 (\N{DEVANAGARI LETTER JA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2313 (\N{DEVANAGARI LETTER U}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2340 (\N{DEVANAGARI LETTER TA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2354 (\N{DEVANAGARI LETTER LA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2381 (\N{DEVANAGARI SIGN VIRAMA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2351 (\N{DEVANAGARI LETTER YA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2328 (\N{DEVANAGARI LETTER GHA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2327 (\N{DEVANAGARI LETTER GA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2369 (\N{DEVANAGARI VOWEL SIGN U}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2337 (\N{DEVANAGARI LETTER DDA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2341 (\N{DEVANAGARI LETTER THA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2367 (\N{DEVANAGARI VOWEL SIGN I}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2343 (\N{DEVANAGARI LETTER DHA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2346 (\N{DEVANAGARI LETTER PA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2349 (\N{DEVANAGARI LETTER BHA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2310 (\N{DEVANAGARI LETTER AA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2377 (\N{DEVANAGARI VOWEL SIGN CANDRA O}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2335 (\N{DEVANAGARI LETTER TTA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2339 (\N{DEVANAGARI LETTER NNA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2311 (\N{DEVANAGARI LETTER I}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2309 (\N{DEVANAGARI LETTER A}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2342 (\N{DEVANAGARI LETTER DA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2336 (\N{DEVANAGARI LETTER TTHA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2333 (\N{DEVANAGARI LETTER JHA}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 2312 (\N{DEVANAGARI LETTER II}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2348 (\N{DEVANAGARI LETTER BA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Matplotlib currently does not support Devanagari natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2366 (\N{DEVANAGARI VOWEL SIGN AA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2355 (\N{DEVANAGARI LETTER LLA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2360 (\N{DEVANAGARI LETTER SA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2361 (\N{DEVANAGARI LETTER HA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2375 (\N{DEVANAGARI VOWEL SIGN E}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2306 (\N{DEVANAGARI SIGN ANUSVARA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2344 (\N{DEVANAGARI LETTER NA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2368 (\N{DEVANAGARI VOWEL SIGN II}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2319 (\N{DEVANAGARI LETTER E}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2325 (\N{DEVANAGARI LETTER KA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2347 (\N{DEVANAGARI LETTER PHA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2379 (\N{DEVANAGARI VOWEL SIGN O}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2357 (\N{DEVANAGARI LETTER VA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2358 (\N{DEVANAGARI LETTER SHA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2370 (\N{DEVANAGARI VOWEL SIGN UU}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2326 (\N{DEVANAGARI LETTER KHA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2330 (\N{DEVANAGARI LETTER CA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2350 (\N{DEVANAGARI LETTER MA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2332 (\N{DEVANAGARI LETTER JA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2313 (\N{DEVANAGARI LETTER U}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2340 (\N{DEVANAGARI LETTER TA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2354 (\N{DEVANAGARI LETTER LA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2381 (\N{DEVANAGARI SIGN VIRAMA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2351 (\N{DEVANAGARI LETTER YA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2328 (\N{DEVANAGARI LETTER GHA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2327 (\N{DEVANAGARI LETTER GA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2369 (\N{DEVANAGARI VOWEL SIGN U}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2337 (\N{DEVANAGARI LETTER DDA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2341 (\N{DEVANAGARI LETTER THA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2367 (\N{DEVANAGARI VOWEL SIGN I}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2343 (\N{DEVANAGARI LETTER DHA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2346 (\N{DEVANAGARI LETTER PA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2349 (\N{DEVANAGARI LETTER BHA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2310 (\N{DEVANAGARI LETTER AA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2377 (\N{DEVANAGARI VOWEL SIGN CANDRA O}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2335 (\N{DEVANAGARI LETTER TTA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2339 (\N{DEVANAGARI LETTER NNA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2311 (\N{DEVANAGARI LETTER I}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2309 (\N{DEVANAGARI LETTER A}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2342 (\N{DEVANAGARI LETTER DA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2336 (\N{DEVANAGARI LETTER TTHA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2333 (\N{DEVANAGARI LETTER JHA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2312 (\N{DEVANAGARI LETTER II}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df_Video_Details['Month'] = pd.to_datetime(df_Video_Details['Published_date']).dt.strftime('%b')

# %%
df_Video_Details
# Out:
#                                                 Title Published_date    Views  \
# 0   अमेरिकेला शह देण्यासाठी जळगावची उभारणी झाली | ...     2021-07-19    87413
# 1   Rekha आणि Smita Patil यांच्यात शेवटपर्यन्त मैत...     2021-07-19     7467
# 2   santoshi mata या सिनेमामुळे sholay सिनेमा फ्लॉ...     2021-07-17     3880
# 3   barshi येथील cancer hospital सुनिल दत्त यांनी ...     2021-07-17    19585
# 4   कोण होत्या इंदिरा गांधींना नडणाऱ्या “पाणीवाली ...     2021-07-17     3052
# 5   Balasaheb thackeray यांच्या विरोधात Arun Gawal...     2021-07-16   219849
# 6   Ajay Devgan आणि kajol .यांच लग्न दोन मिनटात पा...     2021-07-16     4972
# 7   baburao adaskar या बीडच्या आमदारांच्या मिशीचा ...     2021-07-16     9933
# 8   या कारणांमुळे लोकसंख्या नियंत्रण कायद्याला विर...     2021-07-15     1163
# 9   शाहू महाराजांच्या घसरगुंडीची सत्यकथा | Shahu M...     2021-07-15   868713
# 10  या व्यक्तीने वडापावचा शोध लावला | VadaPav | Mu...     2021-07-15   209562
# 11  पवारांचा राष्ट्रपती होण्याचा मार्ग ओरिसातून | ...     2021-07-14     5222
# 12                     नो "ब्रा" चळवळ काय आहे | NoBra     2021-07-14   124512
# 13  धिरूभाईंनी जोरात फिल्डींग लावली, पण समोर प्राम...     2021-07-14    79123
# 14  हाजी मस्तान कसा झाला मुंबईचा डॉन | HajhiMastan...     2021-07-13    57777
# 15  उज्ज्वल निकम हा पवारांचा माणूस आहे | Ujaval Ni...     2021-07-13    73445
# 16  भागवत कराडांसाठी गोपीनाथ मुंडेंनी आपली प्रतिष्...     2021-07-12    10712
# 17  अन् मायकल जॅक्सन तर बप्पी लहरींचा फॅन निघाला |...     2021-07-12     5054
# 18  भारतीयांच्या हातात आलेलं पहिलं रॉकेट RX100 ; प...     2021-07-12   157270
# 19  फक्त तीन तासात अशोक सराफ मराठीचे सुपरस्टार झाल...     2021-07-10    12783
# 20  ती खेळी सुनिल गावसकरांच्या आयुष्यातली सर्वात ख...     2021-07-10     1553
# 21  बाळासाहेबांनी एका फोनवर शाहरूख खानचा माज उतरवल...     2021-07-09  1262462
# 22  ते नसते तर औरंगाबाद आजही एक मोठ्ठं खेडच असत | ...     2021-07-09     3700
# 23  महाराष्ट्राच्या आर्थिक नाड्या आत्ता सहकारमंत्र...     2021-07-08     1878
# 24  मुख्यमंत्री करतो म्हणून नारायण राणेंना ४ वेळा ...     2021-07-08    12011
# 25  One To One | Arvind Jagtap With Sanjay Raut | ...     2021-03-20    19861
# 26  One To One | Promo | Arvind Jagtap With Sanjay...     2021-03-16    14814
# 27  मकरंद अनासपुरेची धमाल. नक्की ऐका #bolbhidu #ma...     2019-08-21     5338
#
#    Month
# 0    Jul
# 1    Jul
# 2    Jul
# 3    Jul
# 4    Jul
# 5    Jul
# 6    Jul
# 7    Jul
# 8    Jul
# 9    Jul
# 10   Jul
# 11   Jul
# 12   Jul
# 13   Jul
# 14   Jul
# 15   Jul
# 16   Jul
# 17   Jul
# 18   Jul
# 19   Jul
# 20   Jul
# 21   Jul
# 22   Jul
# 23   Jul
# 24   Jul
# 25   Mar
# 26   Mar
# 27   Aug

# %%
videos_per_month = df_Video_Details.groupby('Month',as_index=False).size()
videos_per_month
# Out:
#   Month  size
# 0   Aug     1
# 1   Jul    25
# 2   Mar     2
